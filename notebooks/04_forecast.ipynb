# %% [markdown]
# # 04 — Du bao
# Hoi quy tuyen tinh + backtest.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
from src.forecast import run_forecast_pipeline, backtest_last_year
import pandas as pd
by = pd.read_csv(Path.cwd().parent/"outputs/tables/by_year_subject.csv")
print(backtest_last_year(by[by["Mon"]=="Toan"]))
print(run_forecast_pipeline())
