# %% [markdown]
# # 01 — Validate
# Kiem tra file CSV va pham vi nam.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
from src.config import CSV_PATH, YEAR_MIN, YEAR_MAX
from src.load_data import count_rows, iter_chunks
print(CSV_PATH, YEAR_MIN, YEAR_MAX)
print(count_rows())
print(next(iter_chunks(usecols=["Nam","Tinh","Toan"])).head())
