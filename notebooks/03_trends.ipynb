# %% [markdown]
# # 03 — Xu huong
# So sanh diem TB qua cac nam.

# %%
import pandas as pd
from pathlib import Path
ROOT = Path.cwd().parent
by = pd.read_csv(ROOT/"outputs/tables/by_year_subject.csv")
for mon in ["Toan","NguVan","NgoaiNgu"]:
    s = by[by["Mon"]==mon][["Nam","mean"]]
    print(mon)
    print(s.to_string(index=False))
