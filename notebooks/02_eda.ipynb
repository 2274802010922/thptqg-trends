# %% [markdown]
# # 02 — EDA
# Doc bang aggregate hoac tao moi.

# %%
import sys
from pathlib import Path
import pandas as pd
sys.path.insert(0, str(Path.cwd().parent))
from src.aggregates import save_aggregates
from src.config import TABLES_DIR
p = TABLES_DIR / "by_year_subject.csv"
if not p.exists():
    save_aggregates()
df = pd.read_csv(p)
df[df["Mon"]=="Toan"]
